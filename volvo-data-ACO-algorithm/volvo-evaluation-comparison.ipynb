# %%
import pandas as pd

pvt_data_df = pd.read_csv("C:/Users/hp/Documents/GitHub/ACO-Algorithm-For-Solution-Gas-Oil-Ratio-PVT-Correlation/pvt_Data/cleaned_production_data.csv")

# %%
# Out:
#      Date of Production Wellbore name  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0            2013-08-19   15/9-F-11 H          24.00                266.027
# 1            2013-08-20   15/9-F-11 H          24.00                266.560
# 2            2013-08-21   15/9-F-11 H          24.00                266.430
# 3            2013-08-22   15/9-F-11 H          24.00                266.419
# 4            2013-08-23   15/9-F-11 H          24.00                266.416
# ...                 ...           ...            ...                    ...
# 3800         2016-07-02   15/9-F-15 D          24.00                194.984
# 3801         2016-07-03   15/9-F-15 D          24.00                194.978
# 3802         2016-07-04   15/9-F-15 D          24.00                194.317
# 3803         2016-07-05   15/9-F-15 D          24.00                195.207
# 3804         2016-07-06   15/9-F-15 D          18.38                195.306
#
#       AVG_DOWNHOLE_TEMPERATURE  AVG_DP_TUBING  AVG_ANNULUS_PRESS  \
# 0                      105.982        175.275             23.008
# 1                      105.978        175.553             23.037
# 2                      105.995        175.574             23.650
# 3                      106.012        175.626             23.811
# 4                      106.025        175.638             24.032
# ...                        ...            ...                ...
# 3800                   106.518        179.171             21.318
# 3801                   106.516        179.204             21.105
# 3802                   106.521        178.615             21.354
# 3803                   106.507        179.599             20.630
# 3804                   106.507        179.548             20.405
#
#       AVG_CHOKE_SIZE_P  AVG_WHP_P  AVG_WHT_P  DP_CHOKE_SIZE  BORE_OIL_VOL  \
# 0              9.86604     90.752     60.084         62.490        1047.0
# 1              9.81311     91.007     59.501         62.765        1024.0
# 2             10.10168     90.856     59.891         62.611        1050.0
# 3             10.02474     90.793     60.815         62.550        1045.0
# 4             10.08765     90.778     60.124         62.539        1039.0
# ...                ...        ...        ...            ...           ...
# 3800          31.57577     15.813     49.020          1.260         144.0
# 3801          31.54061     15.773     48.988          1.199         145.0
# 3802          31.52210     15.702     50.103          1.280         143.0
# 3803          31.52346     15.608     49.841          1.204         144.0
# 3804          24.92257     15.758     48.734          1.303         106.0
#
#       BORE_GAS_VOL  BORE_WAT_VOL   FLOW_KIND WELL_TYPE  Calculated_GOR
# 0         158557.0          59.0  production        OP      151.439351
# 1         156092.0          59.0  production        OP      152.433594
# 2         160103.0          60.0  production        OP      152.479048
# 3         158665.0          62.0  production        OP      151.832536
# 4         159071.0          59.0  production        OP      153.100096
# ...            ...           ...         ...       ...             ...
# 3800       23201.0         204.0  production        OP      161.118056
# 3801       23068.0         203.0  production        OP      159.089655
# 3802       23060.0         204.0  production        OP      161.258741
# 3803       23090.0         203.0  production        OP      160.347222
# 3804       17537.0         156.0  production        OP      165.443396
#
# [3805 rows x 17 columns]
